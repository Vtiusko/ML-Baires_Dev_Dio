# %%
import matplotlib

# %%
# Para instalar a biblioteca scikit-learn
# >> pip install scikit-learn
from sklearn.datasets import make_regression


# Samples  = Amostra 
# Features = Recurso / valor de cada amostra
# Noise    = Ruído / taxa de erro

x, y = make_regression(n_samples=300, n_features=1, noise=30)
import matplotlib.pyplot as plt

# %%
plt.scatter(x, y)
plt.show()
